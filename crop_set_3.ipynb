# %%
from PIL import Image
import os
import re

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
image_directory = r"C:\Projet_MA1\ML_projet_CNN\projet_cnn\ml-project-2-geraltofryv\dataset\input"
mask_directory = r"C:\Projet_MA1\ML_projet_CNN\projet_cnn\ml-project-2-geraltofryv\dataset\mask"
list_input = os.listdir(image_directory)
list_input
# Out:
# ['set_0_time_0_input.png',
#  'set_0_time_100_input.png',
#  'set_0_time_101_input.png',
#  'set_0_time_102_input.png',
#  'set_0_time_103_input.png',
#  'set_0_time_104_input.png',
#  'set_0_time_105_input.png',
#  'set_0_time_106_input.png',
#  'set_0_time_107_input.png',
#  'set_0_time_108_input.png',
#  'set_0_time_109_input.png',
#  'set_0_time_10_input.png',
#  'set_0_time_110_input.png',
#  'set_0_time_111_input.png',
#  'set_0_time_112_input.png',
#  'set_0_time_113_input.png',
#  'set_0_time_114_input.png',
#  'set_0_time_115_input.png',
#  'set_0_time_116_input.png',
#  'set_0_time_117_input.png',
#  'set_0_time_118_input.png',
#  'set_0_time_119_input.png',
#  'set_0_time_11_input.png',
#  'set_0_time_120_input.png',
#  'set_0_time_12_input.png',
#  'set_0_time_13_input.png',
#  'set_0_time_14_input.png',
#  'set_0_time_15_input.png',
#  'set_0_time_16_input.png',
#  'set_0_time_17_input.png',
#  'set_0_time_18_input.png',
#  'set_0_time_19_input.png',
#  'set_0_time_1_input.png',
#  'set_0_time_20_input.png',
#  'set_0_time_21_input.png',
#  'set_0_time_22_input.png',
#  'set_0_time_23_input.png',
#  'set_0_time_24_input.png',
#  'set_0_time_25_input.png',
#  'set_0_time_26_input.png',
#  'set_0_time_27_input.png',
#  'set_0_time_28_input.png',
#  'set_0_time_29_input.png',
#  'set_0_time_2_input.png',
#  'set_0_time_30_input.png',
#  'set_0_time_31_input.png',
#  'set_0_time_32_input.png',
#  'set_0_time_33_input.png',
#  'set_0_time_34_input.png',
#  'set_0_time_35_input.png',
#  'set_0_time_36_input.png',
#  'set_0_time_37_input.png',
#  'set_0_time_38_input.png',
#  'set_0_time_39_input.png',
#  'set_0_time_3_input.png',
#  'set_0_time_40_input.png',
#  'set_0_time_41_input.png',
#  'set_0_time_42_input.png',
#  'set_0_time_43_input.png',
#  'set_0_time_44_input.png',
#  'set_0_time_45_input.png',
#  'set_0_time_46_input.png',
#  'set_0_time_47_input.png',
#  'set_0_time_48_input.png',
#  'set_0_time_49_input.png',
#  'set_0_time_4_input.png',
#  'set_0_time_50_input.png',
#  'set_0_time_51_input.png',
#  'set_0_time_52_input.png',
#  'set_0_time_53_input.png',
#  'set_0_time_54_input.png',
#  'set_0_time_55_input.png',
#  'set_0_time_56_input.png',
#  'set_0_time_57_input.png',
#  'set_0_time_58_input.png',
#  'set_0_time_59_input.png',
#  'set_0_time_5_input.png',
#  'set_0_time_60_input.png',
#  'set_0_time_61_input.png',
#  'set_0_time_62_input.png',
#  'set_0_time_63_input.png',
#  'set_0_time_64_input.png',
#  'set_0_time_65_input.png',
#  'set_0_time_66_input.png',
#  'set_0_time_67_input.png',
#  'set_0_time_68_input.png',
#  'set_0_time_69_input.png',
#  'set_0_time_6_input.png',
#  'set_0_time_70_input.png',
#  'set_0_time_71_input.png',
#  'set_0_time_72_input.png',
#  'set_0_time_73_input.png',
#  'set_0_time_74_input.png',
#  'set_0_time_75_input.png',
#  'set_0_time_76_input.png',
#  'set_0_time_77_input.png',
#  'set_0_time_78_input.png',
#  'set_0_time_79_input.png',
#  'set_0_time_7_input.png',
#  'set_0_time_80_input.png',
#  'set_0_time_81_input.png',
#  'set_0_time_82_input.png',
#  'set_0_time_83_input.png',
#  'set_0_time_84_input.png',
#  'set_0_time_85_input.png',
#  'set_0_time_86_input.png',
#  'set_0_time_87_input.png',
#  'set_0_time_88_input.png',
#  'set_0_time_89_input.png',
#  'set_0_time_8_input.png',
#  'set_0_time_90_input.png',
#  'set_0_time_91_input.png',
#  'set_0_time_92_input.png',
#  'set_0_time_93_input.png',
#  'set_0_time_94_input.png',
#  'set_0_time_95_input.png',
#  'set_0_time_96_input.png',
#  'set_0_time_97_input.png',
#  'set_0_time_98_input.png',
#  'set_0_time_99_input.png',
#  'set_0_time_9_input.png',
#  'set_1_time_0_input.png',
#  'set_1_time_100_input.png',
#  'set_1_time_101_input.png',
#  'set_1_time_102_input.png',
#  'set_1_time_103_input.png',
#  'set_1_time_104_input.png',
#  'set_1_time_105_input.png',
#  'set_1_time_106_input.png',
#  'set_1_time_107_input.png',
#  'set_1_time_108_input.png',
#  'set_1_time_109_input.png',
#  'set_1_time_10_input.png',
#  'set_1_time_110_input.png',
#  'set_1_time_111_input.png',
#  'set_1_time_112_input.png',
#  'set_1_time_113_input.png',
#  'set_1_time_114_input.png',
#  'set_1_time_115_input.png',
#  'set_1_time_116_input.png',
#  'set_1_time_117_input.png',
#  'set_1_time_118_input.png',
#  'set_1_time_119_input.png',
#  'set_1_time_11_input.png',
#  'set_1_time_120_input.png',
#  'set_1_time_12_input.png',
#  'set_1_time_13_input.png',
#  'set_1_time_14_input.png',
#  'set_1_time_15_input.png',
#  'set_1_time_16_input.png',
#  'set_1_time_17_input.png',
#  'set_1_time_18_input.png',
#  'set_1_time_19_input.png',
#  'set_1_time_1_input.png',
#  'set_1_time_20_input.png',
#  'set_1_time_21_input.png',
#  'set_1_time_22_input.png',
#  'set_1_time_23_input.png',
#  'set_1_time_24_input.png',
#  'set_1_time_25_input.png',
#  'set_1_time_26_input.png',
#  'set_1_time_27_input.png',
#  'set_1_time_28_input.png',
#  'set_1_time_29_input.png',
#  'set_1_time_2_input.png',
#  'set_1_time_30_input.png',
#  'set_1_time_31_input.png',
#  'set_1_time_32_input.png',
#  'set_1_time_33_input.png',
#  'set_1_time_34_input.png',
#  'set_1_time_35_input.png',
#  'set_1_time_36_input.png',
#  'set_1_time_37_input.png',
#  'set_1_time_38_input.png',
#  'set_1_time_39_input.png',
#  'set_1_time_3_input.png',
#  'set_1_time_40_input.png',
#  'set_1_time_41_input.png',
#  'set_1_time_42_input.png',
#  'set_1_time_43_input.png',
#  'set_1_time_44_input.png',
#  'set_1_time_45_input.png',
#  'set_1_time_46_input.png',
#  'set_1_time_47_input.png',
#  'set_1_time_48_input.png',
#  'set_1_time_49_input.png',
#  'set_1_time_4_input.png',
#  'set_1_time_50_input.png',
#  'set_1_time_51_input.png',
#  'set_1_time_52_input.png',
#  'set_1_time_53_input.png',
#  'set_1_time_54_input.png',
#  'set_1_time_55_input.png',
#  'set_1_time_56_input.png',
#  'set_1_time_57_input.png',
#  'set_1_time_58_input.png',
#  'set_1_time_59_input.png',
#  'set_1_time_5_input.png',
#  'set_1_time_60_input.png',
#  'set_1_time_61_input.png',
#  'set_1_time_62_input.png',
#  'set_1_time_63_input.png',
#  'set_1_time_64_input.png',
#  'set_1_time_65_input.png',
#  'set_1_time_66_input.png',
#  'set_1_time_67_input.png',
#  'set_1_time_68_input.png',
#  'set_1_time_69_input.png',
#  'set_1_time_6_input.png',
#  'set_1_time_70_input.png',
#  'set_1_time_71_input.png',
#  'set_1_time_72_input.png',
#  'set_1_time_73_input.png',
#  'set_1_time_74_input.png',
#  'set_1_time_75_input.png',
#  'set_1_time_76_input.png',
#  'set_1_time_77_input.png',
#  'set_1_time_78_input.png',
#  'set_1_time_79_input.png',
#  'set_1_time_7_input.png',
#  'set_1_time_80_input.png',
#  'set_1_time_81_input.png',
#  'set_1_time_82_input.png',
#  'set_1_time_83_input.png',
#  'set_1_time_84_input.png',
#  'set_1_time_85_input.png',
#  'set_1_time_86_input.png',
#  'set_1_time_87_input.png',
#  'set_1_time_88_input.png',
#  'set_1_time_89_input.png',
#  'set_1_time_8_input.png',
#  'set_1_time_90_input.png',
#  'set_1_time_91_input.png',
#  'set_1_time_92_input.png',
#  'set_1_time_93_input.png',
#  'set_1_time_94_input.png',
#  'set_1_time_95_input.png',
#  'set_1_time_96_input.png',
#  'set_1_time_97_input.png',
#  'set_1_time_98_input.png',
#  'set_1_time_99_input.png',
#  'set_1_time_9_input.png',
#  'set_2_time_0_input.png',
#  'set_2_time_100_input.png',
#  'set_2_time_101_input.png',
#  'set_2_time_102_input.png',
#  'set_2_time_103_input.png',
#  'set_2_time_104_input.png',
#  'set_2_time_105_input.png',
#  'set_2_time_106_input.png',
#  'set_2_time_107_input.png',
#  'set_2_time_108_input.png',
#  'set_2_time_109_input.png',
#  'set_2_time_10_input.png',
#  'set_2_time_110_input.png',
#  'set_2_time_111_input.png',
#  'set_2_time_112_input.png',
#  'set_2_time_113_input.png',
#  'set_2_time_114_input.png',
#  'set_2_time_115_input.png',
#  'set_2_time_116_input.png',
#  'set_2_time_117_input.png',
#  'set_2_time_118_input.png',
#  'set_2_time_119_input.png',
#  'set_2_time_11_input.png',
#  'set_2_time_120_input.png',
#  'set_2_time_12_input.png',
#  'set_2_time_13_input.png',
#  'set_2_time_14_input.png',
#  'set_2_time_15_input.png',
#  'set_2_time_16_input.png',
#  'set_2_time_17_input.png',
#  'set_2_time_18_input.png',
#  'set_2_time_19_input.png',
#  'set_2_time_1_input.png',
#  'set_2_time_20_input.png',
#  'set_2_time_21_input.png',
#  'set_2_time_22_input.png',
#  'set_2_time_23_input.png',
#  'set_2_time_24_input.png',
#  'set_2_time_25_input.png',
#  'set_2_time_26_input.png',
#  'set_2_time_27_input.png',
#  'set_2_time_28_input.png',
#  'set_2_time_29_input.png',
#  'set_2_time_2_input.png',
#  'set_2_time_30_input.png',
#  'set_2_time_31_input.png',
#  'set_2_time_32_input.png',
#  'set_2_time_33_input.png',
#  'set_2_time_34_input.png',
#  'set_2_time_35_input.png',
#  'set_2_time_36_input.png',
#  'set_2_time_37_input.png',
#  'set_2_time_38_input.png',
#  'set_2_time_39_input.png',
#  'set_2_time_3_input.png',
#  'set_2_time_40_input.png',
#  'set_2_time_41_input.png',
#  'set_2_time_42_input.png',
#  'set_2_time_43_input.png',
#  'set_2_time_44_input.png',
#  'set_2_time_45_input.png',
#  'set_2_time_46_input.png',
#  'set_2_time_47_input.png',
#  'set_2_time_48_input.png',
#  'set_2_time_49_input.png',
#  'set_2_time_4_input.png',
#  'set_2_time_50_input.png',
#  'set_2_time_51_input.png',
#  'set_2_time_52_input.png',
#  'set_2_time_53_input.png',
#  'set_2_time_54_input.png',
#  'set_2_time_55_input.png',
#  'set_2_time_56_input.png',
#  'set_2_time_57_input.png',
#  'set_2_time_58_input.png',
#  'set_2_time_59_input.png',
#  'set_2_time_5_input.png',
#  'set_2_time_60_input.png',
#  'set_2_time_61_input.png',
#  'set_2_time_62_input.png',
#  'set_2_time_63_input.png',
#  'set_2_time_64_input.png',
#  'set_2_time_65_input.png',
#  'set_2_time_66_input.png',
#  'set_2_time_67_input.png',
#  'set_2_time_68_input.png',
#  'set_2_time_69_input.png',
#  'set_2_time_6_input.png',
#  'set_2_time_70_input.png',
#  'set_2_time_71_input.png',
#  'set_2_time_72_input.png',
#  'set_2_time_73_input.png',
#  'set_2_time_74_input.png',
#  'set_2_time_75_input.png',
#  'set_2_time_76_input.png',
#  'set_2_time_77_input.png',
#  'set_2_time_78_input.png',
#  'set_2_time_79_input.png',
#  'set_2_time_7_input.png',
#  'set_2_time_80_input.png',
#  'set_2_time_81_input.png',
#  'set_2_time_82_input.png',
#  'set_2_time_83_input.png',
#  'set_2_time_84_input.png',
#  'set_2_time_85_input.png',
#  'set_2_time_86_input.png',
#  'set_2_time_87_input.png',
#  'set_2_time_88_input.png',
#  'set_2_time_89_input.png',
#  'set_2_time_8_input.png',
#  'set_2_time_90_input.png',
#  'set_2_time_91_input.png',
#  'set_2_time_92_input.png',
#  'set_2_time_93_input.png',
#  'set_2_time_94_input.png',
#  'set_2_time_95_input.png',
#  'set_2_time_96_input.png',
#  'set_2_time_97_input.png',
#  'set_2_time_98_input.png',
#  'set_2_time_99_input.png',
#  'set_2_time_9_input.png',
#  'set_3_time_0_input.png',
#  'set_3_time_100_input.png',
#  'set_3_time_101_input.png',
#  'set_3_time_102_input.png',
#  'set_3_time_103_input.png',
#  'set_3_time_104_input.png',
#  'set_3_time_105_input.png',
#  'set_3_time_106_input.png',
#  'set_3_time_107_input.png',
#  'set_3_time_108_input.png',
#  'set_3_time_109_input.png',
#  'set_3_time_10_input.png',
#  'set_3_time_110_input.png',
#  'set_3_time_111_input.png',
#  'set_3_time_112_input.png',
#  'set_3_time_113_input.png',
#  'set_3_time_114_input.png',
#  'set_3_time_115_input.png',
#  'set_3_time_116_input.png',
#  'set_3_time_117_input.png',
#  'set_3_time_118_input.png',
#  'set_3_time_119_input.png',
#  'set_3_time_11_input.png',
#  'set_3_time_120_input.png',
#  'set_3_time_12_input.png',
#  'set_3_time_13_input.png',
#  'set_3_time_14_input.png',
#  'set_3_time_15_input.png',
#  'set_3_time_16_input.png',
#  'set_3_time_17_input.png',
#  'set_3_time_18_input.png',
#  'set_3_time_19_input.png',
#  'set_3_time_1_input.png',
#  'set_3_time_20_input.png',
#  'set_3_time_21_input.png',
#  'set_3_time_22_input.png',
#  'set_3_time_23_input.png',
#  'set_3_time_24_input.png',
#  'set_3_time_25_input.png',
#  'set_3_time_26_input.png',
#  'set_3_time_27_input.png',
#  'set_3_time_28_input.png',
#  'set_3_time_29_input.png',
#  'set_3_time_2_input.png',
#  'set_3_time_30_input.png',
#  'set_3_time_31_input.png',
#  'set_3_time_32_input.png',
#  'set_3_time_33_input.png',
#  'set_3_time_34_input.png',
#  'set_3_time_35_input.png',
#  'set_3_time_36_input.png',
#  'set_3_time_37_input.png',
#  'set_3_time_38_input.png',
#  'set_3_time_39_input.png',
#  'set_3_time_3_input.png',
#  'set_3_time_40_input.png',
#  'set_3_time_41_input.png',
#  'set_3_time_42_input.png',
#  'set_3_time_43_input.png',
#  'set_3_time_44_input.png',
#  'set_3_time_45_input.png',
#  'set_3_time_46_input.png',
#  'set_3_time_47_input.png',
#  'set_3_time_48_input.png',
#  'set_3_time_49_input.png',
#  'set_3_time_4_input.png',
#  'set_3_time_50_input.png',
#  'set_3_time_51_input.png',
#  'set_3_time_52_input.png',
#  'set_3_time_53_input.png',
#  'set_3_time_54_input.png',
#  'set_3_time_55_input.png',
#  'set_3_time_56_input.png',
#  'set_3_time_57_input.png',
#  'set_3_time_58_input.png',
#  'set_3_time_59_input.png',
#  'set_3_time_5_input.png',
#  'set_3_time_60_input.png',
#  'set_3_time_61_input.png',
#  'set_3_time_62_input.png',
#  'set_3_time_63_input.png',
#  'set_3_time_64_input.png',
#  'set_3_time_65_input.png',
#  'set_3_time_66_input.png',
#  'set_3_time_67_input.png',
#  'set_3_time_68_input.png',
#  'set_3_time_69_input.png',
#  'set_3_time_6_input.png',
#  'set_3_time_70_input.png',
#  'set_3_time_71_input.png',
#  'set_3_time_72_input.png',
#  'set_3_time_73_input.png',
#  'set_3_time_74_input.png',
#  'set_3_time_75_input.png',
#  'set_3_time_76_input.png',
#  'set_3_time_77_input.png',
#  'set_3_time_78_input.png',
#  'set_3_time_79_input.png',
#  'set_3_time_7_input.png',
#  'set_3_time_80_input.png',
#  'set_3_time_81_input.png',
#  'set_3_time_82_input.png',
#  'set_3_time_83_input.png',
#  'set_3_time_84_input.png',
#  'set_3_time_85_input.png',
#  'set_3_time_86_input.png',
#  'set_3_time_87_input.png',
#  'set_3_time_88_input.png',
#  'set_3_time_89_input.png',
#  'set_3_time_8_input.png',
#  'set_3_time_90_input.png',
#  'set_3_time_91_input.png',
#  'set_3_time_92_input.png',
#  'set_3_time_93_input.png',
#  'set_3_time_94_input.png',
#  'set_3_time_95_input.png',
#  'set_3_time_96_input.png',
#  'set_3_time_97_input.png',
#  'set_3_time_98_input.png',
#  'set_3_time_99_input.png',
#  'set_3_time_9_input.png']

# %%
set_3_list = []
for i,t in enumerate(list_input):
    #print(t.find(f"set_{3}"))
    if t.find(f"set_{3}") != -1:
         set_3_list.append(t)
len(set_3_list)
# Out:
# 121

# %%
set_3_list.sort(key=natural_keys)
set_3_list
# Out:
# ['set_3_time_0_input.png',
#  'set_3_time_1_input.png',
#  'set_3_time_2_input.png',
#  'set_3_time_3_input.png',
#  'set_3_time_4_input.png',
#  'set_3_time_5_input.png',
#  'set_3_time_6_input.png',
#  'set_3_time_7_input.png',
#  'set_3_time_8_input.png',
#  'set_3_time_9_input.png',
#  'set_3_time_10_input.png',
#  'set_3_time_11_input.png',
#  'set_3_time_12_input.png',
#  'set_3_time_13_input.png',
#  'set_3_time_14_input.png',
#  'set_3_time_15_input.png',
#  'set_3_time_16_input.png',
#  'set_3_time_17_input.png',
#  'set_3_time_18_input.png',
#  'set_3_time_19_input.png',
#  'set_3_time_20_input.png',
#  'set_3_time_21_input.png',
#  'set_3_time_22_input.png',
#  'set_3_time_23_input.png',
#  'set_3_time_24_input.png',
#  'set_3_time_25_input.png',
#  'set_3_time_26_input.png',
#  'set_3_time_27_input.png',
#  'set_3_time_28_input.png',
#  'set_3_time_29_input.png',
#  'set_3_time_30_input.png',
#  'set_3_time_31_input.png',
#  'set_3_time_32_input.png',
#  'set_3_time_33_input.png',
#  'set_3_time_34_input.png',
#  'set_3_time_35_input.png',
#  'set_3_time_36_input.png',
#  'set_3_time_37_input.png',
#  'set_3_time_38_input.png',
#  'set_3_time_39_input.png',
#  'set_3_time_40_input.png',
#  'set_3_time_41_input.png',
#  'set_3_time_42_input.png',
#  'set_3_time_43_input.png',
#  'set_3_time_44_input.png',
#  'set_3_time_45_input.png',
#  'set_3_time_46_input.png',
#  'set_3_time_47_input.png',
#  'set_3_time_48_input.png',
#  'set_3_time_49_input.png',
#  'set_3_time_50_input.png',
#  'set_3_time_51_input.png',
#  'set_3_time_52_input.png',
#  'set_3_time_53_input.png',
#  'set_3_time_54_input.png',
#  'set_3_time_55_input.png',
#  'set_3_time_56_input.png',
#  'set_3_time_57_input.png',
#  'set_3_time_58_input.png',
#  'set_3_time_59_input.png',
#  'set_3_time_60_input.png',
#  'set_3_time_61_input.png',
#  'set_3_time_62_input.png',
#  'set_3_time_63_input.png',
#  'set_3_time_64_input.png',
#  'set_3_time_65_input.png',
#  'set_3_time_66_input.png',
#  'set_3_time_67_input.png',
#  'set_3_time_68_input.png',
#  'set_3_time_69_input.png',
#  'set_3_time_70_input.png',
#  'set_3_time_71_input.png',
#  'set_3_time_72_input.png',
#  'set_3_time_73_input.png',
#  'set_3_time_74_input.png',
#  'set_3_time_75_input.png',
#  'set_3_time_76_input.png',
#  'set_3_time_77_input.png',
#  'set_3_time_78_input.png',
#  'set_3_time_79_input.png',
#  'set_3_time_80_input.png',
#  'set_3_time_81_input.png',
#  'set_3_time_82_input.png',
#  'set_3_time_83_input.png',
#  'set_3_time_84_input.png',
#  'set_3_time_85_input.png',
#  'set_3_time_86_input.png',
#  'set_3_time_87_input.png',
#  'set_3_time_88_input.png',
#  'set_3_time_89_input.png',
#  'set_3_time_90_input.png',
#  'set_3_time_91_input.png',
#  'set_3_time_92_input.png',
#  'set_3_time_93_input.png',
#  'set_3_time_94_input.png',
#  'set_3_time_95_input.png',
#  'set_3_time_96_input.png',
#  'set_3_time_97_input.png',
#  'set_3_time_98_input.png',
#  'set_3_time_99_input.png',
#  'set_3_time_100_input.png',
#  'set_3_time_101_input.png',
#  'set_3_time_102_input.png',
#  'set_3_time_103_input.png',
#  'set_3_time_104_input.png',
#  'set_3_time_105_input.png',
#  'set_3_time_106_input.png',
#  'set_3_time_107_input.png',
#  'set_3_time_108_input.png',
#  'set_3_time_109_input.png',
#  'set_3_time_110_input.png',
#  'set_3_time_111_input.png',
#  'set_3_time_112_input.png',
#  'set_3_time_113_input.png',
#  'set_3_time_114_input.png',
#  'set_3_time_115_input.png',
#  'set_3_time_116_input.png',
#  'set_3_time_117_input.png',
#  'set_3_time_118_input.png',
#  'set_3_time_119_input.png',
#  'set_3_time_120_input.png']

# %%
for i, element in enumerate(set_3_list):
    path_im = os.path.join(image_directory, element)
    path_mask = os.path.join(mask_directory, element).replace("_input.png", "_mask.png")
    im = Image.open(path_im)
    mask = Image.open(path_mask)
    width, height = im.size
    #crop from the right side of the image
    left_1 = width - 256
    top_1 = 0
    right_1 = width
    bottom_1 = 256

    im_R = im.crop((left_1, top_1, right_1, bottom_1))
    mask_R = mask.crop((left_1, top_1, right_1, bottom_1))
    
    imR = im_R.save(f"dataset/input/set_3_time_{i}_input.png")
    maskR = mask_R.save(f"dataset/mask/set_3_time_{i}_mask.png")

    #crop from the left size of the image
    left_2 = 0
    top_2 = 0
    right_2 = 256
    bottom_2 = 256
    im_L = im.crop((left_2, top_2, right_2, bottom_2))
    mask_L = mask.crop((left_2, top_2, right_2, bottom_2))
    imL = im_L.save(f"dataset/input/set_4_time_{i}_input.png")
    maskL = mask_L.save(f"dataset/mask/set_4_time_{i}_mask.png")

# %%
path_image = r'C:\Projet_MA1\ML_projet_CNN\projet_cnn\ml-project-2-geraltofryv\dataset\input\set_3_time_112_input.png'
im = Image.open(path_image)
width, height = im.size
print(width, height)
left = 0
top = 0
right = 256
bottom = 256
 
# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))
print(im1.size)
# Shows the image in image viewer
im1.show()
# Out:
# 450 256
# (256, 256)
